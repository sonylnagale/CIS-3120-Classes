# %%
from Animal import Animal
#comment to update
#always reset kernel

# %%
x = Animal("Joe")
#connections
x.talk()
x.alert()
x.feed()
x.alert()
x.play()
x.roaming()
x.awake()
# Out:
# hello, I am Joe
